# %%
import utils
from franken import frk01, frk02, frk03

# %%
for run in range(0, 21):
    utils.RUN = run
    print("RUN:",run)
    r = frk03()
    print("best: ",r,"\n")
# Out:
# RUN: 0
# 0 / 150 : 2019-06-17 18:59:20.501961
# 0 / 150 : 2019-06-17 18:59:20.688166
# 1 / 150 : 2019-06-17 18:59:21.055022
# 2 / 150 : 2019-06-17 18:59:21.392064
# 3 / 150 : 2019-06-17 18:59:21.650593
# 4 / 150 : 2019-06-17 18:59:21.828303
# 5 / 150 : 2019-06-17 18:59:21.922969
# 6 / 150 : 2019-06-17 18:59:21.982112
# 7 / 150 : 2019-06-17 18:59:22.048786
# 8 / 150 : 2019-06-17 18:59:22.110466
# 9 / 150 : 2019-06-17 18:59:22.175873
# 10 / 150 : 2019-06-17 18:59:22.236308
# 11 / 150 : 2019-06-17 18:59:22.295100
# 12 / 150 : 2019-06-17 18:59:22.353482
# 13 / 150 : 2019-06-17 18:59:22.421094
# 14 / 150 : 2019-06-17 18:59:22.477951
# 15 / 150 : 2019-06-17 18:59:22.531762
# 16 / 150 : 2019-06-17 18:59:22.586966
# 17 / 150 : 2019-06-17 18:59:22.643912
# 18 / 150 : 2019-06-17 18:59:22.696972
# 19 / 150 : 2019-06-17 18:59:22.775999
# 20 / 150 : 2019-06-17 18:59:22.833269
# 21 / 150 : 2019-06-17 18:59:22.897447
# 22 / 150 : 2019-06-17 18:59:22.949918
# 23 / 150 : 2019-06-17 18:59:23.009786
# ...
