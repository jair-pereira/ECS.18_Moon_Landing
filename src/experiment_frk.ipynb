# %%
import utils
from franken import frk01, frk02, frk03

# %%
for run in range(0, 21):
    utils.RUN = run
    print("RUN:",run)
    r = frk02()
    print("best: ",r,"\n")
# Out:
# RUN: 0
# 0 / 150 : 2019-06-17 18:52:04.510593
# 0 / 150 : 2019-06-17 18:52:04.702364
# 1 / 150 : 2019-06-17 18:52:05.106268
# 2 / 150 : 2019-06-17 18:52:05.378347
# 3 / 150 : 2019-06-17 18:52:05.583525
# 4 / 150 : 2019-06-17 18:52:05.741264
# 5 / 150 : 2019-06-17 18:52:05.847161
# 6 / 150 : 2019-06-17 18:52:05.935331
# 7 / 150 : 2019-06-17 18:52:06.018056
# 8 / 150 : 2019-06-17 18:52:06.094486
# 9 / 150 : 2019-06-17 18:52:06.171810
# 10 / 150 : 2019-06-17 18:52:06.248283
# 11 / 150 : 2019-06-17 18:52:06.323512
# 12 / 150 : 2019-06-17 18:52:06.385428
# 13 / 150 : 2019-06-17 18:52:06.443522
# 14 / 150 : 2019-06-17 18:52:06.500202
# 15 / 150 : 2019-06-17 18:52:06.560685
# 16 / 150 : 2019-06-17 18:52:06.618126
# 17 / 150 : 2019-06-17 18:52:06.678784
# 18 / 150 : 2019-06-17 18:52:06.743452
# 19 / 150 : 2019-06-17 18:52:06.809234
# 20 / 150 : 2019-06-17 18:52:06.880595
# 21 / 150 : 2019-06-17 18:52:06.954476
# 22 / 150 : 2019-06-17 18:52:07.023684
# 23 / 150 : 2019-06-17 18:52:07.086839
# ...
