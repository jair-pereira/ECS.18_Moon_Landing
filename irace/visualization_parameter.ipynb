# %%
library("irace")
load("./irace_pso.Rdata")
parameterFrequency(iraceResults$allConfigurations, iraceResults$parameters)


load("./irace_de.Rdata")
parameterFrequency(iraceResults$allConfigurations, iraceResults$parameters)
# Out:
# Plotting: n
# Plotting: w
# Plotting: c1
# Plotting: c2
# Plotting: mod
# Plotting: n
# Plotting: beta
# Plotting: pr
# Plotting: mod
# Plot with title “mod”
# Plot with title “mod”
